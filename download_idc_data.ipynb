# %%
from tempfile import TemporaryDirectory
from pathlib import Path
import shutil
import subprocess
from tqdm.auto import tqdm
from textwrap import dedent

# %load_ext google.cloud.bigquery
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %%
task_dir = Path()
dcm_dir = task_dir / "data" / "dcm"
nii_dir = task_dir / "data" / "nii"
dcm_dir.mkdir(exist_ok=True, parents=True)
nii_dir.mkdir(exist_ok=True, parents=True)

# %%
# %%bigquery series_desc
# # Get a list of all the unique series descriptions in the upenn_gbm collection that contain the string "t2"
# SELECT DISTINCT(seriesDescription)
# FROM `bigquery-public-data.idc_current.dicom_all`
# WHERE collection_id IN ('hcc_tace_seg', 'colorectal_liver_metastases') and Modality="CT"
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
# %%bigquery selection_df
# # create list of series to download from upenn_gbm collection that contain the string "t2" in the series description
# SELECT
#   collection_id,
#   PatientID,
#   StudyInstanceUID,
#   SeriesInstanceUID,
#   StudyDate,
#   Modality,
#   StudyDescription,
#   SeriesDescription,
#   # Organize the files in-place on the fly
#   ANY_VALUE(CONCAT("cp s3",
#       REGEXP_SUBSTR(gcs_url, "(://.*)/"),
#       "/* ",collection_id,"/",PatientID,"/",
#       StudyInstanceUID,"/",SeriesInstanceUID)) AS s5cmd_command,
#   COUNT(sopInstanceUID) AS instance_count,
# FROM
#   `bigquery-public-data.idc_current.dicom_all`
# WHERE
#   collection_id IN ('hcc_tace_seg', 'colorectal_liver_metastases') and Modality="CT"
# GROUP BY
#   SeriesInstanceUID,collection_id,PatientID,StudyInstanceUID,SeriesInstanceUID,StudyDate,Modality,StudyDescription,SeriesDescription
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
# save selection dataframe to pickle, useful for further data curation
selection_df.sort_values(
    by=[
        "collection_id",
        "PatientID",
        "StudyDate",
        "StudyInstanceUID",
        "SeriesInstanceUID",
    ],
    inplace=True,
)
pkl_file = task_dir / "data" / "scan_data.pkl"
selection_df.to_pickle(pkl_file)
selection_df.to_csv(pkl_file.with_suffix(".csv"), index=False)

# %% [markdown]
# Download the manifest with s5cmd

# %%
# check the download directory and limit to just the files that are missing
for i, row in selection_df.iterrows():
    dcm_series_dir = dcm_dir / row["s5cmd_command"].split()[-1]
    dcm_cnt = len(list(dcm_series_dir.glob("*.dcm")))
    selection_df.loc[i, "downloaded_cnt"] = dcm_cnt

# %%
# save to file
missing_df = selection_df[
    selection_df["instance_count"] != selection_df["downloaded_cnt"]
]
if len(missing_df) == 0:
    print("all files already downloaded")
else:
    missing_df["s5cmd_command"].to_csv(
        "s5cmd_gcs_missing_manifest.s5cmd", header=False, index=False
    )
    print(
        dedent(
            f"""Run the following commands to download the dcm data
            cd data/dcm
            s5cmd --no-sign-request --endpoint-url https://storage.googleapis.com run {Path("s5cmd_gcs_missing_manifest.s5cmd").resolve()}
            cd -"""
        )
    )

selection_df["s5cmd_command"].to_csv(
    "s5cmd_gcs_manifest.s5cmd", header=False, index=False
)
# Out:
# all files already downloaded

# %% [markdown]
# Convert the files to nifti

# %%
def dcm_to_niix(dcm_dir: Path, nii_path: Path):
    """uses dcm2niix to convert a series of dicom files to a nifti file"""
    with TemporaryDirectory() as tmpdir:
        args = [
            "dcm2niix",
            "-o",
            tmpdir,
            "-z",
            "y",
            str(dcm_dir.resolve()),
        ]
        subprocess.run(args, check=True)

        nii_files = list(Path(tmpdir).glob("*Eq_*.nii.gz"))
        if len(nii_files) > 1:
            raise ValueError(f"Expected 1 Eq_*.nii.gz file, found {len(nii_files)}")
        elif len(nii_files) == 1:
            shutil.move(nii_files[0], nii_path)
            return
        # no Eq images
        nii_files = list(Path(tmpdir).glob("*.nii.gz"))
        if len(nii_files) > 1:
            raise ValueError(f"Expected 1 *.nii.gz file, found {len(nii_files)}")
        elif len(nii_files) == 1:
            shutil.move(nii_files[0], nii_path)
            return
        raise ValueError(f"Expected 1 *.nii.gz file, found 0")

# %%
bad_files = []
dcm_series_dirs = {x.parent for x in dcm_dir.rglob("*.dcm")}
for dcm_series_dir in tqdm(dcm_series_dirs):
    nii_file = nii_dir / f"{dcm_series_dir.relative_to(dcm_dir)}.nii.gz"
    if not nii_file.exists():
        nii_file.parent.mkdir(parents=True, exist_ok=True)
        try:
            dcm_to_niix(dcm_series_dir, nii_file)
        except:
            bad_files.append(dcm_series_dir)
# Out:
#   0%|          | 0/769 [00:00<?, ?it/s]
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 91 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 91 DICOM as /tmp/tmpzjztreuy/1.3.6.1.4.1.14519.5.2.1.1706.8374.205785371691452221491896488464_Recon_3_LIVER_3_PHASE_(AP)_20010902000000_6 (512x512x91x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpzjztreuy/1.3.6.1.4.1.14519.5.2.1.1706.8374.205785371691452221491896488464_Recon_3_LIVER_3_PHASE_(AP)_20010902000000_6.nii"
# Conversion required 0.491137 seconds (0.202795 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 99 DICOM file(s)
# Warning: Empty protocol name(s) (0018,1030)
# Warning: Unable to append protocol name (0018,1030) to filename (it is empty).
# Convert 99 DICOM as /tmp/tmpkn27tkuq/1.3.6.1.4.1.14519.5.2.1.9203.8273.248615515339569718019244079700_19920314104251_101 (512x512x99x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpkn27tkuq/1.3.6.1.4.1.14519.5.2.1.9203.8273.248615515339569718019244079700_19920314104251_101.nii"
# Conversion required 0.595748 seconds (0.198309 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 74 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 74 DICOM as /tmp/tmpc6eigsd4/1.3.6.1.4.1.14519.5.2.1.1706.8374.570467185271981267554249247974_LIVER_2PHASE_CAP_20051112000000_4 (512x512x37x2)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpc6eigsd4/1.3.6.1.4.1.14519.5.2.1.1706.8374.570467185271981267554249247974_LIVER_2PHASE_CAP_20051112000000_4.nii"
# Conversion required 0.317423 seconds (0.132698 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 87 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 87 DICOM as /tmp/tmp3bm1z0pi/1.3.6.1.4.1.14519.5.2.1.1706.8374.754640247306501339419696814053_Recon_2_PRE_LIVER_20020510000000_3 (512x512x87x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp3bm1z0pi/1.3.6.1.4.1.14519.5.2.1.1706.8374.754640247306501339419696814053_Recon_2_PRE_LIVER_20020510000000_3.nii"
# Conversion required 0.436175 seconds (0.205612 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 123 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 123 DICOM as /tmp/tmp0b77ntw7/1.3.6.1.4.1.14519.5.2.1.1706.8374.216955041510241537812995593981_Recon_2_PRE_LIVER_20040508000000_3 (512x512x123x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp0b77ntw7/1.3.6.1.4.1.14519.5.2.1.1706.8374.216955041510241537812995593981_Recon_2_PRE_LIVER_20040508000000_3.nii"
# Conversion required 0.465608 seconds (0.198802 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 46 DICOM file(s)
# Convert 46 DICOM as /tmp/tmpm3qy8mne/1.3.6.1.4.1.14519.5.2.1.9203.8273.282379966485480280674271538733_CT_CAP_19950125173358_2 (512x512x46x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpm3qy8mne/1.3.6.1.4.1.14519.5.2.1.9203.8273.282379966485480280674271538733_CT_CAP_19950125173358_2.nii"
# Conversion required 0.212525 seconds (0.080633 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 85 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 85 DICOM as /tmp/tmp_23z3enr/1.3.6.1.4.1.14519.5.2.1.1706.8374.642066372052476018537189395416_Recon_2_PRE_LIVER_20041106000000_3 (512x512x85x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp_23z3enr/1.3.6.1.4.1.14519.5.2.1.1706.8374.642066372052476018537189395416_Recon_2_PRE_LIVER_20041106000000_3.nii"
# Conversion required 0.363004 seconds (0.160906 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 85 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 85 DICOM as /tmp/tmp0iuoqbp_/1.3.6.1.4.1.14519.5.2.1.1706.8374.231210735618598616486499869783_Recon_2_2_PHASE_LIVER_(ABD)_20030802000000_5 (512x512x85x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp0iuoqbp_/1.3.6.1.4.1.14519.5.2.1.1706.8374.231210735618598616486499869783_Recon_2_2_PHASE_LIVER_(ABD)_20030802000000_5.nii"
# Conversion required 0.362253 seconds (0.162664 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 148 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Warning: Instance Number (0020,0013) order is not spatial.
# Warning: Volume number does not vary (0019,10A2; 0020,0100; 2005,1063; 2005,1413), assuming meaningful instance number (0020,0013).
# Convert 148 DICOM as /tmp/tmpfu7mlaf9/1.3.6.1.4.1.14519.5.2.1.1706.8374.197173974471763845846953652402_Recon_2_LIVER_3_PHASE_(AP)_19980305000000_4 (512x512x74x2)
# Error: Check sorted order: 4D dataset has 2 volumes, but volume index ranges from 1..245
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpfu7mlaf9/1.3.6.1.4.1.14519.5.2.1.1706.8374.197173974471763845846953652402_Recon_2_LIVER_3_PHASE_(AP)_19980305000000_4.nii"
# Conversion required 0.621735 seconds (0.293486 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 79 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 79 DICOM as /tmp/tmpwvweup96/1.3.6.1.4.1.14519.5.2.1.1706.8374.990430729211112437006486676615_Recon_2_LIVER_2PHASE_CAP_20020215000000_5 (512x512x79x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpwvweup96/1.3.6.1.4.1.14519.5.2.1.1706.8374.990430729211112437006486676615_Recon_2_LIVER_2PHASE_CAP_20020215000000_5.nii"
# Conversion required 0.338082 seconds (0.153668 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 36 DICOM file(s)
# Convert 36 DICOM as /tmp/tmpxrt_pl0e/1.3.6.1.4.1.14519.5.2.1.9203.8273.309953836542238933910820230787_CT_CAP_19950416082840_2 (512x512x36x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpxrt_pl0e/1.3.6.1.4.1.14519.5.2.1.9203.8273.309953836542238933910820230787_CT_CAP_19950416082840_2.nii"
# Conversion required 0.189720 seconds (0.064894 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 70 DICOM file(s)
# Warning: Empty protocol name(s) (0018,1030)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Warning: Unable to append protocol name (0018,1030) to filename (it is empty).
# Convert 70 DICOM as /tmp/tmp8_m9uro5/1.3.6.1.4.1.14519.5.2.1.1706.8374.185239472093995010234221516237_19980320000000_105 (512x512x70x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp8_m9uro5/1.3.6.1.4.1.14519.5.2.1.1706.8374.185239472093995010234221516237_19980320000000_105.nii"
# Conversion required 0.443275 seconds (0.145340 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 152 DICOM file(s)
# Convert 152 DICOM as /tmp/tmphhksrvhg/1.3.6.1.4.1.14519.5.2.1.9203.8273.298322421517711990776061950160_CT_CAP_ANGIO_FOR_HEPATIC_PREOP_PLANNING_19950509102850_101 (512x512x152x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmphhksrvhg/1.3.6.1.4.1.14519.5.2.1.9203.8273.298322421517711990776061950160_CT_CAP_ANGIO_FOR_HEPATIC_PREOP_PLANNING_19950509102850_101.nii"
# Conversion required 0.543776 seconds (0.273178 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 141 DICOM file(s)
# Convert 141 DICOM as /tmp/tmpqstd4w5k/1.3.6.1.4.1.14519.5.2.1.9203.8273.295382385963388640484776217390_CT_ABD_ANGIO._LIVER_FOR_PRE-OP_STAGING_19940819121112_101 (512x512x141x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpqstd4w5k/1.3.6.1.4.1.14519.5.2.1.9203.8273.295382385963388640484776217390_CT_ABD_ANGIO._LIVER_FOR_PRE-OP_STAGING_19940819121112_101.nii"
# Conversion required 0.483255 seconds (0.231975 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 74 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Warning: Instance Number (0020,0013) order is not spatial.
# Warning: Interslice distance varies in this volume (incompatible with NIfTI format).
# Warning: Missing images? Expected 74 images, but instance number (0020,0013) ranges from 99 to 1
# Convert 74 DICOM as /tmp/tmphl_g0i6w/1.3.6.1.4.1.14519.5.2.1.1706.8374.397394038804183012526103394838_3_PHASE_LIVER_(ABD)_20010126000000_4 (512x512x74x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmphl_g0i6w/1.3.6.1.4.1.14519.5.2.1.1706.8374.397394038804183012526103394838_3_PHASE_LIVER_(ABD)_20010126000000_4.nii"
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmphl_g0i6w/1.3.6.1.4.1.14519.5.2.1.1706.8374.397394038804183012526103394838_3_PHASE_LIVER_(ABD)_20010126000000_4_Eq_1.nii"
# Conversion required 1.117358 seconds (0.517669 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 20 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 20 DICOM as /tmp/tmptcmcjii9/1.3.6.1.4.1.14519.5.2.1.1706.8374.271551173161741415773802445255_PRE_LIVER_19981009000000_2 (512x512x20x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmptcmcjii9/1.3.6.1.4.1.14519.5.2.1.1706.8374.271551173161741415773802445255_PRE_LIVER_19981009000000_2.nii"
# Conversion required 0.253807 seconds (0.049693 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 95 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 95 DICOM as /tmp/tmpesmnbzwk/1.3.6.1.4.1.14519.5.2.1.1706.8374.287948381321703696238453554957_Recon_2_PRE_LIVER_20040417000000_3 (512x512x95x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpesmnbzwk/1.3.6.1.4.1.14519.5.2.1.1706.8374.287948381321703696238453554957_Recon_2_PRE_LIVER_20040417000000_3.nii"
# Conversion required 0.387698 seconds (0.206155 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 39 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 39 DICOM as /tmp/tmp5lotjl1k/1.3.6.1.4.1.14519.5.2.1.1706.8374.312689390749681454670041277368_PRE_LIVER_19991224000000_2 (512x512x39x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp5lotjl1k/1.3.6.1.4.1.14519.5.2.1.1706.8374.312689390749681454670041277368_PRE_LIVER_19991224000000_2.nii"
# Conversion required 0.184381 seconds (0.062884 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 69 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 69 DICOM as /tmp/tmps4gy80rt/1.3.6.1.4.1.14519.5.2.1.1706.8374.607346132854433511832767843336_Recon_3_LIVER_2PHASE_CAP_20040105000000_6 (512x512x69x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmps4gy80rt/1.3.6.1.4.1.14519.5.2.1.1706.8374.607346132854433511832767843336_Recon_3_LIVER_2PHASE_CAP_20040105000000_6.nii"
# Conversion required 0.266245 seconds (0.119107 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 93 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert
DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 111 DICOM as /tmp/tmp4xv9x254/1.3.6.1.4.1.14519.5.2.1.1706.8374.833585893026670091912920700410_Recon_2_PRE_LIVER_20040724000000_3 (512x512x111x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp4xv9x254/1.3.6.1.4.1.14519.5.2.1.1706.8374.833585893026670091912920700410_Recon_2_PRE_LIVER_20040724000000_3.nii"
# Conversion required 0.589208 seconds (0.234363 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 89 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 89 DICOM as /tmp/tmpnula7niv/1.3.6.1.4.1.14519.5.2.1.1706.8374.312070736225814485342412749460_Recon_2_LIVER_2_PHASE_(C_A_P)_20040417000000_5 (512x512x89x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpnula7niv/1.3.6.1.4.1.14519.5.2.1.1706.8374.312070736225814485342412749460_Recon_2_LIVER_2_PHASE_(C_A_P)_20040417000000_5.nii"
# Conversion required 0.499550 seconds (0.159358 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 157 DICOM file(s)
# Warning: Empty protocol name(s) (0018,1030)
# Warning: Unable to append protocol name (0018,1030) to filename (it is empty).
# Convert 157 DICOM as /tmp/tmpizbzmm08/1.3.6.1.4.1.14519.5.2.1.9203.8273.283158345830440638454362635553_19930207192124_101 (512x512x157x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpizbzmm08/1.3.6.1.4.1.14519.5.2.1.9203.8273.283158345830440638454362635553_19930207192124_101.nii"
# Conversion required 1.022473 seconds (0.298919 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 57 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 57 DICOM as /tmp/tmpx8k157vn/1.3.6.1.4.1.14519.5.2.1.1706.8374.294769342382975256639804025928_Recon_2_LIVER_2_PHASE_(C_A_P)_20040906000000_6 (512x512x57x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpx8k157vn/1.3.6.1.4.1.14519.5.2.1.1706.8374.294769342382975256639804025928_Recon_2_LIVER_2_PHASE_(C_A_P)_20040906000000_6.nii"
# Conversion required 0.468087 seconds (0.104032 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 245 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Slice positions repeated, but number of slices (245) not divisible by number of repeats (3): missing images?
# Warning: Instance Number (0020,0013) order is not spatial.
# Warning: Interslice distance varies in this volume (incompatible with NIfTI format).
# Warning: Missing images? Expected 245 images, but instance number (0020,0013) ranges from 79 to 159
# Warning: Unable to determine slice direction: please check whether slices are flipped
# Convert 245 DICOM as /tmp/tmp6nvfm7rw/1.3.6.1.4.1.14519.5.2.1.1706.8374.213776214865122688712708174786_Recon_2_LIVER_3_PHASE_(AP)_19980523000000_4 (512x512x245x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp6nvfm7rw/1.3.6.1.4.1.14519.5.2.1.1706.8374.213776214865122688712708174786_Recon_2_LIVER_3_PHASE_(AP)_19980523000000_4.nii"
# Unable to equalize slice distances: slice order not consistently ascending:
# dx=[0 0 0 0 2.5 2.5 2.5 5 5 5 7.5 7.5 7.5 10 10 10 12.5 12.5 12.5 15 15 15 17.5 17.5 17.5 20 20 20 22.5 22.5 22.5 25 25 25 27.5 27.5 27.5 30 30 30 32.5 32.5 32.5 35 35 35 37.5 37.5 37.5 40 40 40 42.5 42.5 42.5 45 45 45 47.5 47.5 47.5 50 50 50 52.5 52.5 52.5 55 55 55 57.5 57.5 57.5 60 60 60 62.5 62.5 62.5 65 65 65 67.5 67.5 67.5 70 70 70 72.5 72.5 72.5 75 75 75 77.5 77.5 77.5 80 80 80 82.5 82.5 82.5 85 85 85 87.5 87.5 87.5 90 90 90 92.5 92.5 92.5 95 95 95 97.5 97.5 97.5 100 100 100 102.5 102.5 102.5 105 105 105 107.5 107.5
1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpmyiu9_qu/1.3.6.1.4.1.14519.5.2.1.1706.8374.489872120073574349734745881040_Recon_3_LIVER_3_PHASE_(AP)_19980816000000_5.nii"
# Conversion required 0.770003 seconds (0.164235 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 121 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 121 DICOM as /tmp/tmpl8qbzpbn/1.3.6.1.4.1.14519.5.2.1.1706.8374.212665247771039281214268872539_Recon_3_LIVER_3_PHASE_(AP)_20011214000000_6 (512x512x121x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpl8qbzpbn/1.3.6.1.4.1.14519.5.2.1.1706.8374.212665247771039281214268872539_Recon_3_LIVER_3_PHASE_(AP)_20011214000000_6.nii"
# Conversion required 0.916650 seconds (0.247767 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 103 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 103 DICOM as /tmp/tmpqr0pfcv3/1.3.6.1.4.1.14519.5.2.1.1706.8374.263849801555598764028487376499_Recon_2_PRE_LIVER_20010407000000_3 (512x512x103x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpqr0pfcv3/1.3.6.1.4.1.14519.5.2.1.1706.8374.263849801555598764028487376499_Recon_2_PRE_LIVER_20010407000000_3.nii"
# Conversion required 0.478129 seconds (0.208061 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 26 DICOM file(s)
# Convert 26 DICOM as /tmp/tmpyz3hp9t9/1.3.6.1.4.1.14519.5.2.1.9203.8273.187405215983989324227505234366_CT_CAP_19921225113616_2 (512x512x26x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpyz3hp9t9/1.3.6.1.4.1.14519.5.2.1.9203.8273.187405215983989324227505234366_CT_CAP_19921225113616_2.nii"
# Conversion required 0.154062 seconds (0.051855 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 55 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 55 DICOM as /tmp/tmp6jvofrdk/1.3.6.1.4.1.14519.5.2.1.1706.8374.717453583626480566870305402063_PRE_LIVER_20040709000000_2 (512x512x55x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp6jvofrdk/1.3.6.1.4.1.14519.5.2.1.1706.8374.717453583626480566870305402063_PRE_LIVER_20040709000000_2.nii"
# Conversion required 0.246990 seconds (0.096385 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 97 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 97 DICOM as /tmp/tmpjbskz581/1.3.6.1.4.1.14519.5.2.1.1706.8374.301825340779721734489903304923_Recon_3_LIVER_2_PHASE_(C_A_P)_20030120000000_6 (512x512x97x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpjbskz581/1.3.6.1.4.1.14519.5.2.1.1706.8374.301825340779721734489903304923_Recon_3_LIVER_2_PHASE_(C_A_P)_20030120000000_6.nii"
# Conversion required 0.387635 seconds (0.178766 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 134 DICOM file(s)
# Convert 134 DICOM as /tmp/tmpasswtq3u/1.3.6.1.4.1.14519.5.2.1.9203.8273.124808983199574540456814027616_CT_CAP_ANGIO_FOR_HEPATIC_PREOP_PLANNING_19931215111733_101 (512x512x134x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpasswtq3u/1.3.6.1.4.1.14519.5.2.1.9203.8273.124808983199574540456814027616_CT_CAP_ANGIO_FOR_HEPATIC_PREOP_PLANNING_19931215111733_101.nii"
# Conversion required 0.576569 seconds (0.240011 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 48 DICOM file(s)
# Convert 48 DICOM as /tmp/tmp76r1eg0n/1.3.6.1.4.1.14519.5.2.1.9203.8273.397194625682377596463554592309_CT_CH_ABD_PEL_19950103174733_2 (512x512x48x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp76r1eg0n/1.3.6.1.4.1.14519.5.2.1.9203.8273.397194625682377596463554592309_CT_CH_ABD_PEL_19950103174733_2.nii"
# Conversion required 0.258733 seconds (0.088193 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 182 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Warning: Instance Number (0020,0013) order is not spatial.
# Warning: Interslice distance varies in this volume (incompatible with NIfTI format).
# Convert 182 DICOM as /tmp/tmp96kjgaaj/1.3.6.1.4.1.14519.5.2.1.1706.8374.125380608918489434089516114619_2.5_STANDARD_20060516000000_6 (512x512x182x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tm
for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 79 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 79 DICOM as /tmp/tmporlgg186/1.3.6.1.4.1.14519.5.2.1.1706.8374.118000366957942305399625207879_Recon_2_LIVER_3_PHASE_(C_A_P)_19981229000000_4 (512x512x79x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmporlgg186/1.3.6.1.4.1.14519.5.2.1.1706.8374.118000366957942305399625207879_Recon_2_LIVER_3_PHASE_(C_A_P)_19981229000000_4.nii"
# Conversion required 0.262893 seconds (0.115726 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 162 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 162 DICOM as /tmp/tmpy9umt6ns/1.3.6.1.4.1.14519.5.2.1.1706.8374.332424215968991956405444812674_2.5_STANDARD_20060708000000_7 (512x512x81x2)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpy9umt6ns/1.3.6.1.4.1.14519.5.2.1.1706.8374.332424215968991956405444812674_2.5_STANDARD_20060708000000_7.nii"
# Conversion required 0.460476 seconds (0.232686 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 77 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 77 DICOM as /tmp/tmptq1enx_1/1.3.6.1.4.1.14519.5.2.1.1706.8374.136142978609094228680670121332_Recon_3_LIVER_2_PHASE_(C_A_P)_20031020000000_6 (512x512x77x1)
# ...
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpxmjszdlm/1.3.6.1.4.1.14519.5.2.1.1706.8374.281794707607472372257121510727_Recon_2_LIVER_2PHASE_CAP_20020413000000_5.nii"
# Conversion required 0.657960 seconds (0.243989 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 141 DICOM file(s)
# Convert 141 DICOM as /tmp/tmp67h802j6/1.3.6.1.4.1.14519.5.2.1.9203.8273.754562685270871439945801984624_CT_CAP_ANGIO_FOR_HEPATIC_PREOP_PLANNING_19920914172807_101 (512x512x141x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp67h802j6/1.3.6.1.4.1.14519.5.2.1.9203.8273.754562685270871439945801984624_CT_CAP_ANGIO_FOR_HEPATIC_PREOP_PLANNING_19920914172807_101.nii"
# Conversion required 0.510355 seconds (0.275543 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 24 DICOM file(s)
# Convert 24 DICOM as /tmp/tmp2hfrthyx/1.3.6.1.4.1.14519.5.2.1.9203.8273.327303485422462715065085862890_CT_CAP_19920624093137_2 (512x512x24x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp2hfrthyx/1.3.6.1.4.1.14519.5.2.1.9203.8273.327303485422462715065085862890_CT_CAP_19920624093137_2.nii"
# Conversion required 0.113416 seconds (0.036785 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 99 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 99 DICOM as /tmp/tmph43x7qgg/1.3.6.1.4.1.14519.5.2.1.1706.8374.250553969166017238492363988409_Recon_2_LIVER_3_PHASE_(AP)_20020202000000_5 (512x512x99x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmph43x7qgg/1.3.6.1.4.1.14519.5.2.1.1706.8374.250553969166017238492363988409_Recon_2_LIVER_3_PHASE_(AP)_20020202000000_5.nii"
# Conversion required 0.299565 seconds (0.143211 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 151 DICOM file(s)
# Convert 151 DICOM as /tmp/tmp99ggv8fm/1.3.6.1.4.1.14519.5.2.1.9203.8273.861281401253753035062018600477_CT_CAP_ANGIO_FOR_HEPATIC_PREOP_PLANNING_19940131173307_101 (512x512x151x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp99ggv8fm/1.3.6.1.4.1.14519.5.2.1.9203.8273.861281401253753035062018600477_CT_CAP_ANGIO_FOR_HEPATIC_PREOP_PLANNING_19940131173307_101.nii"
# Conversion required 0.576976 seconds (0.240810 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 43 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 43 DICOM as /tmp/tmpj_lgxxnt/1.3.6.1.4.1.14519.5.2.1.1706.8374.627555238882741198866137859811_PRE_LIVER_20000623000000_2 (512x512x43x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpj_lgxxnt/1.3.6.1.4.1.14519.5.2.1.1706.8374.627555238882741198866137859811_PRE_LIVER_20000623000000_2.nii"
# Conversion required 0.163213 seconds (0.061474 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 71 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 71 DICOM as /tmp/tmpu8q_eds7/1.3.6.1.4.1.14519.5.2.1.1706.8374.313581991792459084954574750119_Recon_2_LIVER_3_PHASE_(AP)_20000214000000_4 (512x512x71x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpu8q_eds7/1.3.6.1.4.1.14519.5.2.1.1706.8374.313581991792459084954574750119_Recon_2_LIVER_3_PHASE_(AP)_20000214000000_4.nii"
# Conversion required 0.232706 seconds (0.102412 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 51 DICOM file(s)
# Convert 51 DICOM as /tmp/tmp_i15ozl3/1.3.6.1.4.1.14519.5.2.1.9203.8273.647078994044139971307880938775_CT_CAP_19941229101839_2 (512x512x51x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp_i15ozl3/1.3.6.1.4.1.14519.5.2.1.9203.8273.647078994044139971307880938775_CT_CAP_19941229101839_2.nii"
# Conversion required 0.209430 seconds (0.084772 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 87 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 87 DICOM as /tmp/tmposbo2y1i/1.3.6.1.4.1.14519.5.2.1.1706.8374.301780920377039805379112696474_Recon_2_PRE_LIVER_20010630000000_3 (512x512x87x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmposbo2y1i/1.3.6.1.4.1.14519.5.2.1.1706.8374.301780920377039805379112696474_Recon_2_PRE_LIVER_20010630000000_3.nii"
# Conversion required 0.272845 seconds (0.124686 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 107 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 107 DICOM as /tmp/tmpd1xlvpea/1.3.6.1.4.1.14519.5.2.1.1706.8374.192613899626100958752138398673_Recon_2_PRE_LIVER_20030615000000_3 (512x512x107x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpd1xlvpea/1.3.6.1.4.1.14519.5.2.1.1706.8374.192613899626100958752138398673_Recon_2_PRE_LIVER_20030615000000_3.nii"
# Conversion required 0.527240 seconds (0.189263 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 77 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 77 DICOM as /tmp/tmp_qutenf_/1.3.6.1.4.1.14519.5.2.1.1706.8374.155007980057127298628789221350_Recon_2_PRE_LIVER_20050508000000_3 (512x512x77x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp_qutenf_/1.3.6.1.4.1.14519.5.2.1.1706.8374.155007980057127298628789221350_Recon_2_PRE_LIVER_20050508000000_3.nii"
# Conversion required 0.273589 seconds (0.137157 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 63 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 63 DICOM as /tmp/tmp930lu2ct/1.3.6.1.4.1.14519.5.2.1.1706.8374.276287113926887340104314003334_Recon_2_LIVER_3_PHASE_(AP)_19980922000000_4 (512x512x63x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp930lu2ct/1.3.6.1.4.1.14519.5.2.1.1706.8374.276287113926887340104314003334_Recon_2_LIVER_3_PHASE_(AP)_19980922000000_4.nii"
# Conversion required 0.351961 seconds (0.106591 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 93 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 93 DICOM as /tmp/tmpo3txnb7z/1.3.6.1.4.1.14519.5.2.1.1706.8374.262756677630713439082865671571_Recon_2_LIVER_2_PHASE_(C_A_P)_20041106000000_5 (512x512x93x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpo3txnb7z/1.3.6.1.4.1.14519.5.2.1.1706.8374.262756677630713439082865671571_Recon_2_LIVER_2_PHASE_(C_A_P)_20041106000000_5.nii"
# Conversion required 0.672686 seconds (0.168188 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 69 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 69 DICOM as /tmp/tmpy5goy82q/1.3.6.1.4.1.14519.5.2.1.1706.8374.183867280992437959358499257292_Recon_3_LIVER_3_PHASE_(C_A_P)_19991024000000_6 (512x512x69x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpy5goy82q/1.3.6.1.4.1.14519.5.2.1.1706.8374.183867280992437959358499257292_Recon_3_LIVER_3_PHASE_(C_A_P)_19991024000000_6.nii"
# Conversion required 0.367772 seconds (0.128879 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 117 DICOM file(s)
# Convert 117 DICOM as /tmp/tmpf638h27y/1.3.6.1.4.1.14519.5.2.1.9203.8273.207339518727715932140231193509_CT_CAP_ANGIO_FOR_HEPATIC_PREOP_PLANNING_19921116165544_101 (512x512x117x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpf638h27y/1.3.6.1.4.1.14519.5.2.1.9203.8273.207339518727715932140231193509_CT_CAP_ANGIO_FOR_HEPATIC_PREOP_PLANNING_19921116165544_101.nii"
# Conversion required 0.340100 seconds (0.171128 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 99 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 99 DICOM as /tmp/tmpqob8jmas/1.3.6.1.4.1.14519.5.2.1.1706.8374.174241682431274053343754640946_Recon_3_LIVER_2_PHASE_WITH_CON_20041206000000_6 (512x512x99x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpqob8jmas/1.3.6.1.4.1.14519.5.2.1.1706.8374.174241682431274053343754640946_Recon_3_LIVER_2_PHASE_WITH_CON_20041206000000_6.nii"
# Conversion required 0.451686 seconds (0.183824 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 79 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 79 DICOM as /tmp/tmp7qhorivz/1.3.6.1.4.1.14519.5.2.1.1706.8374.152736372150870476573273929134_Recon_3_LIVER_3_PHASE_(C_A_P)_20000818000000_6 (512x512x79x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp7qhorivz/1.3.6.1.4.1.14519.5.2.1.1706.8374.152736372150870476573273929134_Recon_3_LIVER_3_PHASE_(C_A_P)_20000818000000_6.nii"
# Conversion required 0.244713 seconds (0.114791 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 95 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 95 DICOM as /tmp/tmpikslci9m/1.3.6.1.4.1.14519.5.2.1.1706.8374.264724304155526783931876335427_2.5_STANDARD_20060419000000_3 (512x512x95x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpikslci9m/1.3.6.1.4.1.14519.5.2.1.1706.8374.264724304155526783931876335427_2.5_STANDARD_20060419000000_3.nii"
# Conversion required 0.655408 seconds (0.168126 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 198 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Warning: Instance Number (0020,0013) order is not spatial.
# Warning: Interslice distance varies in this volume (incompatible with NIfTI format).
# Warning: Missing images? Expected 198 images, but instance number (0020,0013) ranges from 198 to 88
# Convert 198 DICOM as /tmp/tmpnglj7ya1/1.3.6.1.4.1.14519.5.2.1.1706.8374.170783408818161305996891396696_2.5_STANDARD_20060121000000_5 (512x512x198x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpnglj7ya1/1.3.6.1.4.1.14519.5.2.1.1706.8374.170783408818161305996891396696_2.5_STANDARD_20060121000000_5.nii"
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpnglj7ya1/1.3.6.1.4.1.14519.5.2.1.1706.8374.170783408818161305996891396696_2.5_STANDARD_20060121000000_5_Eq_1.nii"
# Conversion required 1.950436 seconds (1.121860 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 122 DICOM file(s)
# Convert 122 DICOM as /tmp/tmp_i3v7vpn/1.3.6.1.4.1.14519.5.2.1.9203.8273.240128136332449570479291119998_CT_ABD_ANGIO._FOR_HEPATIC_SURGERY_PLANNING_19940107122438_101 (512x512x122x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp_i3v7vpn/1.3.6.1.4.1.14519.5.2.1.9203.8273.240128136332449570479291119998_CT_ABD_ANGIO._FOR_HEPATIC_SURGERY_PLANNING_19940107122438_101.nii"
# Conversion required 0.381989 seconds (0.214392 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 89 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 89 DICOM as /tmp/tmpp36brao3/1.3.6.1.4.1.14519.5.2.1.1706.8374.334241984775526142750401219077_Recon_2_PRE_LIVER_20041206000000_3 (512x512x89x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpp36brao3/1.3.6.1.4.1.14519.5.2.1.1706.8374.334241984775526142750401219077_Recon_2_PRE_LIVER_20041206000000_3.nii"
# Conversion required 0.258028 seconds (0.118636 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 39 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 39 DICOM as /tmp/tmpafpfu80o/1.3.6.1.4.1.14519.5.2.1.1706.8374.724912092432506677547285814354_PRE_LIVER_19990321000000_2 (512x512x39x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpafpfu80o/1.3.6.1.4.1.14519.5.2.1.1706.8374.724912092432506677547285814354_PRE_LIVER_19990321000000_2.nii"
# Conversion required 0.217674 seconds (0.069167 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 206 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 206 DICOM as /tmp/tmp2mu9afzj/1.3.6.1.4.1.14519.5.2.1.1706.8374.102236702835548398521518585145_2.5_STANDARD_20051101000000_7 (512x512x103x2)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp2mu9afzj/1.3.6.1.4.1.14519.5.2.1.1706.8374.102236702835548398521518585145_2.5_STANDARD_20051101000000_7.nii"
# Conversion required 0.656074 seconds (0.372119 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 111 DICOM file(s)
# Convert 111 DICOM as /tmp/tmpy2a1u4pk/1.3.6.1.4.1.14519.5.2.1.9203.8273.251444380193534656305097589516_6.26_CT_#213_CAP_ANGIO_FOR_HEPATIC_PREOP_PLANNING_19921130120028_101 (512x512x111x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpy2a1u4pk/1.3.6.1.4.1.14519.5.2.1.9203.8273.251444380193534656305097589516_6.26_CT_#213_CAP_ANGIO_FOR_HEPATIC_PREOP_PLANNING_19921130120028_101.nii"
# Conversion required 0.354956 seconds (0.173999 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 39 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 39 DICOM as /tmp/tmpmr7k01be/1.3.6.1.4.1.14519.5.2.1.1706.8374.260593496279114390758754886026_PRE_LIVER_20000709000000_2 (512x512x39x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpmr7k01be/1.3.6.1.4.1.14519.5.2.1.1706.8374.260593496279114390758754886026_PRE_LIVER_20000709000000_2.nii"
# Conversion required 0.169507 seconds (0.067619 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 105 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 105 DICOM as /tmp/tmp_nawvz76/1.3.6.1.4.1.14519.5.2.1.1706.8374.169986415710267266411401328999_Recon_2_PRE_LIVER_20001020000000_3 (512x512x105x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmp_nawvz76/1.3.6.1.4.1.14519.5.2.1.1706.8374.169986415710267266411401328999_Recon_2_PRE_LIVER_20001020000000_3.nii"
# Conversion required 0.330608 seconds (0.155367 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 63 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 63 DICOM as /tmp/tmpw7g7ds_l/1.3.6.1.4.1.14519.5.2.1.1706.8374.420948697639669926408418265539_Recon_2_LIVER_2PHASE_WITH_CON_20031007000000_5 (512x512x63x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmpw7g7ds_l/1.3.6.1.4.1.14519.5.2.1.1706.8374.420948697639669926408418265539_Recon_2_LIVER_2PHASE_WITH_CON_20031007000000_5.nii"
# Conversion required 0.218271 seconds (0.093209 for core code).
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC11.3.0 x86-64 (64-bit Linux)
# Found 77 DICOM file(s)
# Warning: Unable to determine manufacturer (0008,0070), so conversion is not tuned for vendor.
# Convert 77 DICOM as /tmp/tmphh44cg_s/1.3.6.1.4.1.14519.5.2.1.1706.8374.275974482001693881129687846177_Recon_2_LIVER_3_PHASE_(AP)_20010226000000_6 (512x512x77x1)
# Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/tmp/tmphh44cg_s/1.3.6.1.4.1.14519.5.2.1.1706.8374.275974482001693881129687846177_Recon_2_LIVER_3_PHASE_(AP)_20010226000000_6.nii"
# Conversion required 0.326310 seconds (0.125143 for core code).

# %%
len(bad_files)
# Out:
# 1
